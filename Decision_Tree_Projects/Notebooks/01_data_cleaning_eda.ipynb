# %% [markdown]
# ### Importing the Libraries and Data File

# %%
import pandas as pd

df = pd.read_csv("Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Preliminary Analysis of the dataset.

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Checking for Null Values.

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Obtaining some Statistics of the Data.

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ### Identifying the Features and Targets.

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# ### Splitting Feature Types - Critical for Decision Trees.

# %%
target = 'Churn'

numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).drop(columns=[target]).columns

numerical_features, categorical_features
# Out:
# (Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object'),
#  Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#         'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#         'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#         'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges'],
#        dtype='object'))

# %%
df['TotalCharges'].head()
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# Name: TotalCharges, dtype: object

# %% [raw]
# TotalCharges is stored as an object type not Numeric. This needs to be corrected.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# #### There are now 11 missing values. Customers with tenure = 0 -> TotalCharges = 0. These will be filled with the value = 0

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)
df["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1    1889.50
# 2     108.15
# 3    1840.75
# 4     151.65
# 5     820.50
# 6    1949.40
# 7     301.90
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: float64

# %% [markdown]
# ### Target encoding (Binary Conversion)

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})
df["Churn"].head(10)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    0
# Name: Churn, dtype: int64

# %% [markdown]
# ### Dropping the Customer ID column. Keeping the CustomerID's adds to the noise.

# %%
df = df.drop(columns=['customerID'])

# %% [markdown]
# ### Churn Rate - Expected Churn rate should be 20-30%.

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# #### The results above, shows that the Churn Rate is imbalanced.

# %% [markdown]
# ### Tenure vs Churn.

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# 0    37.569965
# 1    17.979133
# Name: tenure, dtype: float64

# %% [markdown]
# #### NOTE: Customers who churn have significantly lower tenure, indicating that Tenure is a likely strong split feature in the tree.

# %% [markdown]
# ### Looking at Contract Type vs Churn.

# %%
pd.crosstab(df['Contract'], df['Churn'], normalize='index')
# Out:
# Churn                  0         1
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %% [markdown]
# #### Looks like Month-to-Month contracts for more than the other.

# %% [markdown]
# ### Encoding Categorical Variables using One-Hot-Encoding.

# %%
df_encoded = pd.get_dummies(df, drop_first=True)
df_encoded.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  gender_Male  \
# 0              0       1           29.85         29.85      0        False
# 1              0      34           56.95       1889.50      0         True
# 2              0       2           53.85        108.15      1         True
# 3              0      45           42.30       1840.75      0         True
# 4              0       2           70.70        151.65      1        False
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
# 3        False           False             False
# 4        False           False              True
#
#    MultipleLines_No phone service  ...  StreamingTV_No internet service  \
# 0                            True  ...                            False
# ...

# %% [markdown]
# ### Saving the Cleaned DataFrame as a Pickle File.

# %%
df_encoded.to_pickle("churn_data_cleaned.pkl")
